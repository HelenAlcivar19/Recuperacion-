# %%
import pandas as pd
import numpy as np 
from sqlalchemy import create_engine
from sqlalchemy import Table, Column, Integer, String, MetaData, ForeignKey
from sqlalchemy import inspect
from sqlalchemy import MetaData
import sqlite3
import datetime
import sqlalchemy

# %% [markdown]
# Limpieza de datos
# EXTRACCION

# %%
dfHA = pd.read_csv("Building_Permits.csv")
dfHA.head(10)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (22,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
# 5  201706149344            8            otc alterations permit
# 6  201706300814            8            otc alterations permit
# 7       M803667            8            otc alterations permit
# 8       M804227            8            otc alterations permit
# 9       M804767            8            otc alterations permit
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# 3           11/07/2016  0156  011           1230                  NaN
# 4           11/28/2016  0342  001            950                  NaN
# 5           06/14/2017  4105  009            800                  NaN
# 6           06/30/2017  1739  020           1291                  NaN
# 7           06/30/2017  4789  014           1465                  NaN
# 8           07/05/2017  1212  054           2094                  NaN
# 9           07/06/2017  1259  016             89                  NaN
#
#   Street Name Street Suffix  ...  Existing Construction Type  \
# 0       Ellis            St  ...                         3.0
# 1       Geary            St  ...                         3.0
# 2     Pacific            Av  ...                         1.0
# 3     Pacific            Av  ...                         5.0
# 4      Market            St  ...                         3.0
# 5     Indiana            St  ...                         1.0
# 6        11th            Av  ...                         5.0
# 7      Revere            Av  ...                         NaN
# 8        Fell            St  ...                         NaN
# 9      Alpine            Tr  ...                         NaN
#
#   Existing Construction Type Description Proposed Construction Type  \
# 0                          constr type 3                        NaN
# 1                          constr type 3                        NaN
# 2                          constr type 1                        1.0
# 3                         wood frame (5)                        5.0
# 4                          constr type 3                        NaN
# 5                          constr type 1                        1.0
# 6                         wood frame (5)                        5.0
# 7                                    NaN                        NaN
# 8                                    NaN                        NaN
# 9                                    NaN                        NaN
#
#   Proposed Construction Type Description Site Permit Supervisor District  \
# 0                                    NaN         NaN                 3.0
# 1                                    NaN         NaN                 3.0
# 2                          constr type 1         NaN                 3.0
# 3                         wood frame (5)         NaN                 3.0
# 4                                    NaN         NaN                 6.0
# 5                          constr type 1         NaN                10.0
# 6                         wood frame (5)         NaN                 5.0
# 7                                    NaN         NaN                10.0
# 8                                    NaN         NaN                 5.0
# 9                                    NaN         NaN                 8.0
#
#   Neighborhoods - Analysis Boundaries  Zipcode  \
# 0                          Tenderloin  94102.0
# 1                          Tenderloin  94102.0
# 2                        Russian Hill  94109.0
# 3                            Nob Hill  94109.0
# 4                          Tenderloin  94102.0
# 5                        Potrero Hill  94107.0
# 6                        Inner Sunset  94122.0
# 7               Bayview Hunters Point  94124.0
# 8                   Lone Mountain/USF  94117.0
# 9                      Haight Ashbury  94117.0
#
#                                     Location     Record ID
# 0  (37.785719256680785, -122.40852313194863)  1.380611e+12
# 1   (37.78733980600732, -122.41063199757738)  1.420164e+12
# 2    (37.7946573324287, -122.42232562979227)  1.424857e+12
# 3   (37.79595867909168, -122.41557405519474)  1.443574e+12
# 4   (37.78315261897309, -122.40950883997789)  1.445482e+11
# 5   (37.75922331346539, -122.39170402628598)  1.466911e+12
# 6  (37.764145640138565, -122.46875112470363)  1.468970e+12
# 7   (37.73005099023611, -122.38784938916618)  1.469035e+12
# 8  (37.772393498502595, -122.45231466824669)  1.469198e+12
# 9    (37.7691724293766, -122.43734859051908)  1.469324e+11
#
# [10 rows x 43 columns]

# %% [markdown]
# transformacion de datos

# %%
dfHA.dropna().isnull()
dfHA.head(10)
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
# 5  201706149344            8            otc alterations permit
# 6  201706300814            8            otc alterations permit
# 7       M803667            8            otc alterations permit
# 8       M804227            8            otc alterations permit
# 9       M804767            8            otc alterations permit
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# 3           11/07/2016  0156  011           1230                  NaN
# 4           11/28/2016  0342  001            950                  NaN
# 5           06/14/2017  4105  009            800                  NaN
# 6           06/30/2017  1739  020           1291                  NaN
# 7           06/30/2017  4789  014           1465                  NaN
# 8           07/05/2017  1212  054           2094                  NaN
# 9           07/06/2017  1259  016             89                  NaN
#
#   Street Name Street Suffix  ...  Existing Construction Type  \
# 0       Ellis            St  ...                         3.0
# 1       Geary            St  ...                         3.0
# 2     Pacific            Av  ...                         1.0
# 3     Pacific            Av  ...                         5.0
# 4      Market            St  ...                         3.0
# 5     Indiana            St  ...                         1.0
# 6        11th            Av  ...                         5.0
# 7      Revere            Av  ...                         NaN
# 8        Fell            St  ...                         NaN
# 9      Alpine            Tr  ...                         NaN
#
#   Existing Construction Type Description Proposed Construction Type  \
# 0                          constr type 3                        NaN
# 1                          constr type 3                        NaN
# 2                          constr type 1                        1.0
# 3                         wood frame (5)                        5.0
# 4                          constr type 3                        NaN
# 5                          constr type 1                        1.0
# 6                         wood frame (5)                        5.0
# 7                                    NaN                        NaN
# 8                                    NaN                        NaN
# 9                                    NaN                        NaN
#
#   Proposed Construction Type Description Site Permit Supervisor District  \
# 0                                    NaN         NaN                 3.0
# 1                                    NaN         NaN                 3.0
# 2                          constr type 1         NaN                 3.0
# 3                         wood frame (5)         NaN                 3.0
# 4                                    NaN         NaN                 6.0
# 5                          constr type 1         NaN                10.0
# 6                         wood frame (5)         NaN                 5.0
# 7                                    NaN         NaN                10.0
# 8                                    NaN         NaN                 5.0
# 9                                    NaN         NaN                 8.0
#
#   Neighborhoods - Analysis Boundaries  Zipcode  \
# 0                          Tenderloin  94102.0
# 1                          Tenderloin  94102.0
# 2                        Russian Hill  94109.0
# 3                            Nob Hill  94109.0
# 4                          Tenderloin  94102.0
# 5                        Potrero Hill  94107.0
# 6                        Inner Sunset  94122.0
# 7               Bayview Hunters Point  94124.0
# 8                   Lone Mountain/USF  94117.0
# 9                      Haight Ashbury  94117.0
#
#                                     Location     Record ID
# 0  (37.785719256680785, -122.40852313194863)  1.380611e+12
# 1   (37.78733980600732, -122.41063199757738)  1.420164e+12
# 2    (37.7946573324287, -122.42232562979227)  1.424857e+12
# 3   (37.79595867909168, -122.41557405519474)  1.443574e+12
# 4   (37.78315261897309, -122.40950883997789)  1.445482e+11
# 5   (37.75922331346539, -122.39170402628598)  1.466911e+12
# 6  (37.764145640138565, -122.46875112470363)  1.468970e+12
# 7   (37.73005099023611, -122.38784938916618)  1.469035e+12
# 8  (37.772393498502595, -122.45231466824669)  1.469198e+12
# 9    (37.7691724293766, -122.43734859051908)  1.469324e+11
#
# [10 rows x 43 columns]

# %% [markdown]
# llenar datos faltantes

# %%
dfHA.fillna(method='bfill', axis=0).fillna(0)
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 164497  201612013946            8            otc alterations permit
# 164498  201612013904            8            otc alterations permit
# 164499  201612024079            8            otc alterations permit
# 164500  201612074396            8            otc alterations permit
# 164501  201612074397            8            otc alterations permit
#
#        Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0                05/06/2015  0326  023            140                    A
# 1                04/19/2016  0306  007            440                    A
# 2                05/27/2016  0595  203           1647                    A
# 3                11/07/2016  0156  011           1230                    A
# 4                11/28/2016  0342  001            950                    A
# ...                     ...   ...  ...            ...                  ...
# 164497           12/01/2016  0513  010           2490                    0
# 164498           12/01/2016  3642  019           3266                    0
# 164499           12/02/2016  1805  016           1473                    0
# 164500           12/07/2016  0596  002           1849                    0
# 164501           12/07/2016  0596  002           1849                    0
#
#        Street Name Street Suffix  ...  Existing Construction Type  \
# 0            Ellis            St  ...                         3.0
# 1            Geary            St  ...                         3.0
# 2          Pacific            Av  ...                         1.0
# 3          Pacific            Av  ...                         5.0
# 4           Market            St  ...                         3.0
# ...            ...           ...  ...                         ...
# 164497     Filbert            St  ...                         5.0
# 164498        24th            St  ...                         5.0
# 164499        48th            Av  ...                         5.0
# 164500      Larkin            St  ...                         5.0
# 164501      Larkin            St  ...                         5.0
#
#        Existing Construction Type Description Proposed Construction Type  \
# 0                               constr type 3                        1.0
# 1                               constr type 3                        1.0
# 2                               constr type 1                        1.0
# 3                              wood frame (5)                        5.0
# 4                               constr type 3                        1.0
# ...                                       ...                        ...
# 164497                         wood frame (5)                        5.0
# 164498                         wood frame (5)                        5.0
# 164499                         wood frame (5)                        5.0
# 164500                         wood frame (5)                        5.0
# 164501                         wood frame (5)                        5.0
#
#        Proposed Construction Type Description Site Permit Supervisor District  \
# 0                               constr type 1           Y                 3.0
# 1                               constr type 1           Y                 3.0
# 2                               constr type 1           Y                 3.0
# 3                              wood frame (5)           Y                 3.0
# 4                               constr type 1           Y                 6.0
# ...                                       ...         ...                 ...
# 164497                         wood frame (5)           0                 2.0
# 164498                         wood frame (5)           0                 9.0
# 164499                         wood frame (5)           0                 4.0
# 164500                         wood frame (5)           0                 3.0
# 164501                         wood frame (5)           0                 3.0
#
#        Neighborhoods - Analysis Boundaries  Zipcode  \
# 0                               Tenderloin  94102.0
# 1                               Tenderloin  94102.0
# 2                             Russian Hill  94109.0
# 3                                 Nob Hill  94109.0
# 4                               Tenderloin  94102.0
# ...                                    ...      ...
# 164497                              Marina  94123.0
# 164498                             Mission  94110.0
# 164499                     Sunset/Parkside  94122.0
# 164500                        Russian Hill  94109.0
# 164501                                   0      0.0
#
#                                          Location     Record ID
# 0       (37.785719256680785, -122.40852313194863)  1.380611e+12
# 1        (37.78733980600732, -122.41063199757738)  1.420164e+12
# 2         (37.7946573324287, -122.42232562979227)  1.424857e+12
# 3        (37.79595867909168, -122.41557405519474)  1.443574e+12
# 4        (37.78315261897309, -122.40950883997789)  1.445482e+11
# ...                                           ...           ...
# 164497   (37.79770949836049, -122.44037643532758)  1.446041e+11
# 164498   (37.75249406266713, -122.41781004248826)  1.445982e+12
# 164499  (37.758972810340175, -122.50830114426145)  1.446222e+12
# 164500     (37.794990980504, -122.42020070167871)  1.446675e+12
# 164501                                          0  0.000000e+00
#
# [164502 rows x 43 columns]

# %% [markdown]
# Identificacionde registros duplicados

# %%
dfHA.columns.duplicated()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False])

# %% [markdown]
# Eliminacion

# %%
dfHA.drop_duplicates()
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 164497  201612013946            8            otc alterations permit
# 164498  201612013904            8            otc alterations permit
# 164499  201612024079            8            otc alterations permit
# 164500  201612074396            8            otc alterations permit
# 164501  201612074397            8            otc alterations permit
#
#        Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0                05/06/2015  0326  023            140                  NaN
# 1                04/19/2016  0306  007            440                  NaN
# 2                05/27/2016  0595  203           1647                  NaN
# 3                11/07/2016  0156  011           1230                  NaN
# 4                11/28/2016  0342  001            950                  NaN
# ...                     ...   ...  ...            ...                  ...
# 164497           12/01/2016  0513  010           2490                  NaN
# 164498           12/01/2016  3642  019           3266                  NaN
# 164499           12/02/2016  1805  016           1473                  NaN
# 164500           12/07/2016  0596  002           1849                  NaN
# 164501           12/07/2016  0596  002           1849                  NaN
#
#        Street Name Street Suffix  ...  Existing Construction Type  \
# 0            Ellis            St  ...                         3.0
# 1            Geary            St  ...                         3.0
# 2          Pacific            Av  ...                         1.0
# 3          Pacific            Av  ...                         5.0
# 4           Market            St  ...                         3.0
# ...            ...           ...  ...                         ...
# 164497     Filbert            St  ...                         5.0
# 164498        24th            St  ...                         5.0
# 164499        48th            Av  ...                         5.0
# 164500      Larkin            St  ...                         5.0
# 164501      Larkin            St  ...                         5.0
#
#        Existing Construction Type Description Proposed Construction Type  \
# 0                               constr type 3                        NaN
# 1                               constr type 3                        NaN
# 2                               constr type 1                        1.0
# 3                              wood frame (5)                        5.0
# 4                               constr type 3                        NaN
# ...                                       ...                        ...
# 164497                         wood frame (5)                        5.0
# 164498                         wood frame (5)                        5.0
# 164499                         wood frame (5)                        5.0
# 164500                         wood frame (5)                        5.0
# 164501                         wood frame (5)                        5.0
#
#        Proposed Construction Type Description Site Permit Supervisor District  \
# 0                                         NaN         NaN                 3.0
# 1                                         NaN         NaN                 3.0
# 2                               constr type 1         NaN                 3.0
# 3                              wood frame (5)         NaN                 3.0
# 4                                         NaN         NaN                 6.0
# ...                                       ...         ...                 ...
# 164497                         wood frame (5)         NaN                 2.0
# 164498                         wood frame (5)         NaN                 9.0
# 164499                         wood frame (5)         NaN                 4.0
# 164500                         wood frame (5)         NaN                 3.0
# 164501                         wood frame (5)         NaN                 3.0
#
#        Neighborhoods - Analysis Boundaries  Zipcode  \
# 0                               Tenderloin  94102.0
# 1                               Tenderloin  94102.0
# 2                             Russian Hill  94109.0
# 3                                 Nob Hill  94109.0
# 4                               Tenderloin  94102.0
# ...                                    ...      ...
# 164497                              Marina  94123.0
# 164498                             Mission  94110.0
# 164499                     Sunset/Parkside  94122.0
# 164500                        Russian Hill  94109.0
# 164501                                 NaN      NaN
#
#                                          Location     Record ID
# 0       (37.785719256680785, -122.40852313194863)  1.380611e+12
# 1        (37.78733980600732, -122.41063199757738)  1.420164e+12
# 2         (37.7946573324287, -122.42232562979227)  1.424857e+12
# 3        (37.79595867909168, -122.41557405519474)  1.443574e+12
# 4        (37.78315261897309, -122.40950883997789)  1.445482e+11
# ...                                           ...           ...
# 164497   (37.79770949836049, -122.44037643532758)  1.446041e+11
# 164498   (37.75249406266713, -122.41781004248826)  1.445982e+12
# 164499  (37.758972810340175, -122.50830114426145)  1.446222e+12
# 164500     (37.794990980504, -122.42020070167871)  1.446675e+12
# 164501                                        NaN           NaN
#
# [164502 rows x 43 columns]

# %% [markdown]
# eliminacion de espacion en blanco

# %%
dfHA.replace(' ','')
dfHA.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# 3           11/07/2016  0156  011           1230                  NaN
# 4           11/28/2016  0342  001            950                  NaN
#
#   Street Name Street Suffix  ...  Existing Construction Type  \
# 0       Ellis            St  ...                         3.0
# 1       Geary            St  ...                         3.0
# 2     Pacific            Av  ...                         1.0
# 3     Pacific            Av  ...                         5.0
# 4      Market            St  ...                         3.0
#
#   Existing Construction Type Description Proposed Construction Type  \
# 0                          constr type 3                        NaN
# 1                          constr type 3                        NaN
# 2                          constr type 1                        1.0
# 3                         wood frame (5)                        5.0
# 4                          constr type 3                        NaN
#
#   Proposed Construction Type Description Site Permit Supervisor District  \
# 0                                    NaN         NaN                 3.0
# 1                                    NaN         NaN                 3.0
# 2                          constr type 1         NaN                 3.0
# 3                         wood frame (5)         NaN                 3.0
# 4                                    NaN         NaN                 6.0
#
#   Neighborhoods - Analysis Boundaries  Zipcode  \
# 0                          Tenderloin  94102.0
# 1                          Tenderloin  94102.0
# 2                        Russian Hill  94109.0
# 3                            Nob Hill  94109.0
# 4                          Tenderloin  94102.0
#
#                                     Location     Record ID
# 0  (37.785719256680785, -122.40852313194863)  1.380611e+12
# 1   (37.78733980600732, -122.41063199757738)  1.420164e+12
# 2    (37.7946573324287, -122.42232562979227)  1.424857e+12
# 3   (37.79595867909168, -122.41557405519474)  1.443574e+12
# 4   (37.78315261897309, -122.40950883997789)  1.445482e+11
#
# [5 rows x 43 columns]

# %% [markdown]
# cambio de case

# %%
dfHA['Description'] = dfHA['Description'].str.upper()
dfHA['Permit Type Definition'] = dfHA['Permit Type Definition'].str.upper()
dfHA['Street Name'] = dfHA['Street Name'].str.upper()
dfHA['Neighborhoods - Analysis Boundaries'] = dfHA['Neighborhoods - Analysis Boundaries'].str.upper()
dfHA['Existing Construction Type Description'] = dfHA['Existing Construction Type Description'].str.upper()
dfHA['Proposed Construction Type Description'] = dfHA['Proposed Construction Type Description'].str.upper()
dfHA['Current Status'] = dfHA['Current Status'].str.upper()
dfHA['Existing Use'] = dfHA['Existing Use'].str.upper()
dfHA.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      SIGN - ERECT
# 1  201604195146            4                      SIGN - ERECT
# 2  201605278609            3  ADDITIONS ALTERATIONS OR REPAIRS
# 3  201611072166            8            OTC ALTERATIONS PERMIT
# 4  201611283529            6                       DEMOLITIONS
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# 3           11/07/2016  0156  011           1230                  NaN
# 4           11/28/2016  0342  001            950                  NaN
#
#   Street Name Street Suffix  ...  Existing Construction Type  \
# 0       ELLIS            St  ...                         3.0
# 1       GEARY            St  ...                         3.0
# 2     PACIFIC            Av  ...                         1.0
# 3     PACIFIC            Av  ...                         5.0
# 4      MARKET            St  ...                         3.0
#
#   Existing Construction Type Description Proposed Construction Type  \
# 0                          CONSTR TYPE 3                        NaN
# 1                          CONSTR TYPE 3                        NaN
# 2                          CONSTR TYPE 1                        1.0
# 3                         WOOD FRAME (5)                        5.0
# 4                          CONSTR TYPE 3                        NaN
#
#   Proposed Construction Type Description Site Permit Supervisor District  \
# 0                                    NaN         NaN                 3.0
# 1                                    NaN         NaN                 3.0
# 2                          CONSTR TYPE 1         NaN                 3.0
# 3                         WOOD FRAME (5)         NaN                 3.0
# 4                                    NaN         NaN                 6.0
#
#   Neighborhoods - Analysis Boundaries  Zipcode  \
# 0                          TENDERLOIN  94102.0
# 1                          TENDERLOIN  94102.0
# 2                        RUSSIAN HILL  94109.0
# 3                            NOB HILL  94109.0
# 4                          TENDERLOIN  94102.0
#
#                                     Location     Record ID
# 0  (37.785719256680785, -122.40852313194863)  1.380611e+12
# 1   (37.78733980600732, -122.41063199757738)  1.420164e+12
# 2    (37.7946573324287, -122.42232562979227)  1.424857e+12
# 3   (37.79595867909168, -122.41557405519474)  1.443574e+12
# 4   (37.78315261897309, -122.40950883997789)  1.445482e+11
#
# [5 rows x 43 columns]

# %% [markdown]
# llena de datos completos

# %%
dfHA['Fire Only Permit'] = dfHA['Fire Only Permit'].fillna('N')
dfHA['Unit'] = dfHA['Unit'].fillna('0')
print(dfHA['Fire Only Permit'])
# Out:
# 0         N
# 1         N
# 2         N
# 3         N
# 4         N
#          ..
# 164497    N
# 164498    N
# 164499    N
# 164500    N
# 164501    N
# Name: Fire Only Permit, Length: 164502, dtype: object

# %% [markdown]
# eliminacionde colunmas no  necesarias

# %%
dfHA = dfHA.drop(columns=['Site Permit'])
dfHA = dfHA.drop(columns=['TIDF Compliance'])
dfHA = dfHA.drop(columns=['Street Number Suffix'])
dfHA = dfHA.drop(columns=['Structural Notification'])
dfHA = dfHA.drop(columns=['Existing Units'])
dfHA = dfHA.drop(columns=['Voluntary Soft-Story Retrofit'])
dfHA = dfHA.drop(columns=['Proposed Construction Type'])
dfHA = dfHA.drop(columns=['Unit Suffix'])

dfHA.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      SIGN - ERECT
# 1  201604195146            4                      SIGN - ERECT
# 2  201605278609            3  ADDITIONS ALTERATIONS OR REPAIRS
# 3  201611072166            8            OTC ALTERATIONS PERMIT
# 4  201611283529            6                       DEMOLITIONS
#
#   Permit Creation Date Block  Lot  Street Number Street Name Street Suffix  \
# 0           05/06/2015  0326  023            140       ELLIS            St
# 1           04/19/2016  0306  007            440       GEARY            St
# 2           05/27/2016  0595  203           1647     PACIFIC            Av
# 3           11/07/2016  0156  011           1230     PACIFIC            Av
# 4           11/28/2016  0342  001            950      MARKET            St
#
#   Unit  ... Proposed Units Plansets Existing Construction Type  \
# 0    0  ...            NaN      2.0                        3.0
# 1  0.0  ...            NaN      2.0                        3.0
# 2    0  ...           39.0      2.0                        1.0
# 3  0.0  ...            1.0      2.0                        5.0
# 4    0  ...            NaN      2.0                        3.0
#
#   Existing Construction Type Description  \
# 0                          CONSTR TYPE 3
# 1                          CONSTR TYPE 3
# 2                          CONSTR TYPE 1
# 3                         WOOD FRAME (5)
# 4                          CONSTR TYPE 3
#
#   Proposed Construction Type Description Supervisor District  \
# 0                                    NaN                 3.0
# 1                                    NaN                 3.0
# 2                          CONSTR TYPE 1                 3.0
# 3                         WOOD FRAME (5)                 3.0
# 4                                    NaN                 6.0
#
#   Neighborhoods - Analysis Boundaries  Zipcode  \
# 0                          TENDERLOIN  94102.0
# 1                          TENDERLOIN  94102.0
# 2                        RUSSIAN HILL  94109.0
# 3                            NOB HILL  94109.0
# 4                          TENDERLOIN  94102.0
#
#                                     Location     Record ID
# 0  (37.785719256680785, -122.40852313194863)  1.380611e+12
# 1   (37.78733980600732, -122.41063199757738)  1.420164e+12
# 2    (37.7946573324287, -122.42232562979227)  1.424857e+12
# 3   (37.79595867909168, -122.41557405519474)  1.443574e+12
# 4   (37.78315261897309, -122.40950883997789)  1.445482e+11
#
# [5 rows x 35 columns]

# %% [markdown]
# contar valores faltantes

# %%
dfHA.isnull().sum()
# Out:
# Permit Number                                 0
# Permit Type                                   0
# Permit Type Definition                        0
# Permit Creation Date                          0
# Block                                         0
# Lot                                           0
# Street Number                                 0
# Street Name                                   0
# Street Suffix                              2310
# Unit                                          0
# Description                                 256
# Current Status                                0
# Current Status Date                           0
# Filed Date                                    0
# Issued Date                               10016
# Completed Date                            79709
# First Construction Document Date          10028
# Number of Existing Stories                37401
# Number of Proposed Stories                37634
# Fire Only Permit                              0
# Permit Expiration Date                    42621
# Estimated Cost                            33532
# Revised Cost                               4253
# Existing Use                              36038
# Proposed Use                              37271
# Proposed Units                            44211
# Plansets                                  32939
# Existing Construction Type                37901
# Existing Construction Type Description    37901
# Proposed Construction Type Description    37880
# Supervisor District                        1603
# Neighborhoods - Analysis Boundaries        1610
# Zipcode                                    1604
# Location                                   1591
# Record ID                                     1
# dtype: int64

# %%
df = pd.DataFrame(dfHA)

df_re = df[['Zipcode','Location']]
df_re['id_Permit'] = df_re.index
df_re['id_Record'] = df_re.index
df_re['Neighborhoods_Analysis'] = df_re.index
df_re.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    Zipcode                                   Location  id_Permit  id_Record  \
# 0  94102.0  (37.785719256680785, -122.40852313194863)          0          0
# 1  94102.0   (37.78733980600732, -122.41063199757738)          1          1
# 2  94109.0    (37.7946573324287, -122.42232562979227)          2          2
# 3  94109.0   (37.79595867909168, -122.41557405519474)          3          3
# 4  94102.0   (37.78315261897309, -122.40950883997789)          4          4
#
#    Neighborhoods_Analysis
# 0                       0
# 1                       1
# 2                       2
# 3                       3
# 4                       4

# %%
df = pd.DataFrame(dfHA)

df_per = df[['Permit Number','Permit Type','Permit Type Definition','Permit Creation Date']]
df_per.columns = ['Permit_Number','Permit_Type','Permit_Type_Definition','Permit_Creation_Date']
df_per['id_street'] = df_per.index

df_per.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#   Permit_Number  Permit_Type            Permit_Type_Definition  \
# 0  201505065519            4                      SIGN - ERECT
# 1  201604195146            4                      SIGN - ERECT
# 2  201605278609            3  ADDITIONS ALTERATIONS OR REPAIRS
# 3  201611072166            8            OTC ALTERATIONS PERMIT
# 4  201611283529            6                       DEMOLITIONS
#
#   Permit_Creation_Date  id_street
# 0           05/06/2015          0
# 1           04/19/2016          1
# 2           05/27/2016          2
# 3           11/07/2016          3
# 4           11/28/2016          4
